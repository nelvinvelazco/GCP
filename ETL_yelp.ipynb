# %%
import pandas as pd

# %%
json_reader = pd.read_json('D:/PROYECTO FINAL/Yelp/review/parte_1.json')

# %%
json_reader
# Out:
#                      review_id                 user_id  \
# 0       KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1       BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2       saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3       AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4       Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                        ...                     ...
# 699023  R2eQ0TC5nEBOHxePI0OYsA  Fg7UkdjVcNrzhAcMdj6hrA
# 699024  1b6hqG3kxGNlnAT9nRUEgw  dIjjuh5hWTi2vyXvHLaT1w
# 699025  JJvQTAlZnXfEdiTHhUPrHw  LysfhpQwnQlV8a0a4SjY0A
# 699026  SVU0-3mOX_lTmbpN8sZdhg  vEFYRzXLBtOGYC3ZPwr9Jw
# 699027  jTl31zZo5BgKK1rITLl7KA  -d3fw1hcLWaQOoLGv-29Vw
#
#                    business_id  stars  useful  funny  cool  \
# 0       XQfwVwDr-v0ZS3_CbbE5Xw      3       0      0     0
# 1       7ATYjTIgM3jUlt4UM3IypQ      5       1      0     1
# 2       YjUWPpI6HXG530lwP-fb2A      3       0      0     0
# 3       kxX2SOes4o-D3ZQBkiMRfA      5       1      0     1
# 4       e4Vwtrqf-wpJfwesgvdgxQ      4       1      0     1
# ...                        ...    ...     ...    ...   ...
# 699023  6S9kohYoS25IHOnVMOFoEQ      5       2      1     1
# 699024  j9Kaj_6tSeXmVMYCgZithg      4       2      0     0
# 699025  eqNutOMnPqKa9QDAY6KfEw      5       0      0     0
# 699026  s_ATCd6WGLEFvW4GNBBBUg      3       1      0     0
# 699027  nvb8SFi1-LzaQHEhUnw_7g      4       0      0     1
#
#                                                      text                date
# 0       If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1       I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2       Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3       Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4       Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# ...                                                   ...                 ...
# 699023  Dear God, thank you for concocting the slow ea... 2015-07-15 23:04:02
# 699024  Was in town for a sporting event and stopped i... 2021-12-18 13:55:17
# 699025  I'm so thrilled to discover this wonderful Fre... 2022-01-15 19:33:31
# 699026  We were excited and hopeful to try this restau... 2022-01-15 00:46:49
# 699027  We like to visit Gators when we are at Treasur... 2012-05-19 12:00:58
#
# [699028 rows x 9 columns]

# %%
def dividir_json_grande(archivo_entrada, num_partes):
    # Contar el número total de líneas/objetos en el archivo JSON
    with open(archivo_entrada, 'r', encoding='utf-8') as archivo:
        total_lineas = sum(1 for _ in archivo)
    
    # Calcular el tamaño de cada parte
    tamaño_parte = total_lineas // num_partes
    if total_lineas % num_partes != 0:
        tamaño_parte += 1

    # Leer y dividir el archivo en partes
    with open(archivo_entrada, 'r', encoding='utf-8') as archivo:
        for i in range(num_partes):
            archivo_salida = f'parte_{i + 1}.json'
            with open(archivo_salida, 'w', encoding='utf-8') as salida:
                salida.write('[')  # Comenzar un array JSON
                for j in range(tamaño_parte):
                    linea = archivo.readline()
                    if not linea:
                        break
                    salida.write(linea.rstrip())
                    if j < tamaño_parte - 1 and not archivo.tell() == total_lineas:
                        salida.write(',')
                salida.write(']')  # Terminar el array JSON
            # Si el archivo original ha terminado, salir del bucle
            if not linea:
                break

# Usar la función para dividir el archivo 'archivo.json' en 10 partes
dividir_json_grande('D:/PROYECTO FINAL/Yelp/review.json', 10)
